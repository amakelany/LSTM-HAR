# %%
! git clone https://github.com/amakelany/LSTM-Human-Activity-Recognition
# Out:
# Cloning into 'LSTM-Human-Activity-Recognition'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 135 (delta 22), reused 0 (delta 0), pack-reused 99
# Receiving objects: 100% (135/135), 1.40 MiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
cd LSTM-Human-Activity-Recognition/
# Out:
# /content/LSTM-Human-Activity-Recognition

# %%
run LSTM.ipynb
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /content/LSTM-Human-Activity-Recognition
# data  LICENSE  LSTM_files  LSTM.ipynb  README.md
# /content/LSTM-Human-Activity-Recognition/data
# download_dataset.py  source.txt
#
# Downloading...
# --2022-02-23 20:29:39--  https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60999314 (58M) [application/x-httpd-php]
# Saving to: ‘UCI HAR Dataset.zip’
#
# ...
